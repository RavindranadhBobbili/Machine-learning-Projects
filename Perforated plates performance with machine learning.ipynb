# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = LabelEncoder()
for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, training_scores_encoded)
y_model = model.predict(x_test)
import seaborn as sns
sns.heatmap(df, square=True, annot=True, cbar=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-892b4464bc61> in <module>
#      11             df[column] = le.fit_transform(df[column])
#      12 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
# ---> 13 clf = RandomForestClassifier(random_state=0, n_jobs=-1)
#      14 from sklearn import preprocessing
#      15 from sklearn import utils
#
# NameError: name 'RandomForestClassifier' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = LabelEncoder()
for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, training_scores_encoded)
y_model = model.predict(x_test)
import seaborn as sns
sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = LabelEncoder()
for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, training_scores_encoded)
y_model = model.predict(x_test)
import seaborn as sns
sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
clf = RandomForestClassifier(random_state=0, n_jobs=-1)
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y)
# Train model
model = clf.fit(x, training_scores_encoded)
importances = model.feature_importances_
# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]
# Create plot
plt.figure()
# Create plot title
plt.title("Feature Importance")
# Add bars
plt.bar(range(x.shape[1]), importances[indices])
# Add feature names as x-axis labels
plt.xticks(range(x.shape[1]), names, rotation=90)
# Show plot
plt.show()
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2f854eeb2a14> in <module>
#      23 plt.bar(range(x.shape[1]), importances[indices])
#      24 # Add feature names as x-axis labels
# ---> 25 plt.xticks(range(x.shape[1]), names, rotation=90)
#      26 # Show plot
#      27 plt.show()
#
# NameError: name 'names' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
print('Accuracy of Logistic regression classifier on training set: {:.2f}'
     .format(logreg.score(X_train, y_train)))
print('Accuracy of Logistic regression classifier on test set: {:.2f}'
     .format(logreg.score(X_test, y_test)))
# Out:
# Accuracy of Logistic regression classifier on training set: 0.58
# Accuracy of Logistic regression classifier on test set: 0.33
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:334: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x_train,y_train)
y_pred= classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-89222ffb814c> in <module>
#      16 from sklearn.metrics import classification_report, confusion_matrix
#      17 from sklearn import metrics
# ---> 18 accuracy_score(y_test, y_pred)
#      19 print(confusion_matrix(y_test, pred_y))
#      20 print(classification_report(y_test, pred_y))
#
# NameError: name 'accuracy_score' is not defined

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x_train,y_train)
pred_y= classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred_y)
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-87ab107db292> in <module>
#      18 from sklearn.metrics import accuracy_score
#      19 accuracy_score(y_test, y_pred)
# ---> 20 print(confusion_matrix(y_test, pred_y))
#      21 print(classification_report(y_test, pred_y))
#
# NameError: name 'pred_y' is not defined

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=0)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x_train,y_train)
pred_y= classifier.predict(x_test)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred_y)
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[2 0 4]
#  [0 0 0]
#  [0 1 2]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.33      0.50         6
#         NP/P       0.00      0.00      0.00         0
#         P/NP       0.33      0.67      0.44         3
#
#    micro avg       0.44      0.44      0.44         9
#    macro avg       0.44      0.33      0.31         9
# weighted avg       0.78      0.44      0.48         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1145: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
import seaborn as sns
sns.heatmap(x1.corr(), annot=True)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
#     Projectile  Velocity  P Plate thick  B Plate thick  Test result
# 0            0         5              2              0            1
# 1            0         8              2              0            2
# 2            0         7              2              0            0
# 3            0         2              2              0            0
# 4            0         3              2              0            2
# 5            0         9              2              0            3
# 6            0         0              2              0            3
# 7            0         1              2              0            2
# 8            0         6              2              0            2
# 9            0        15              1              1            0
# 10           0        13              1              1            0
# 11           0        17              1              1            0
# 12           0        10              1              1            2
# 13           0        12              1              1            0
# 14           0        14              1              1            2
# 15           0         4              1              1            2
# 16           0         3              1              1            0
# 17           0        11              0              1            3
# 18           0        16              0              1            3
# 19           0        32              2              1            0
# 20           0        33              2              1            0
# 21           1        30              2              1            2
# 22           1        31              2              1            0
# 23           1        29              2              1            2
# 24           1        27              2              1            3
# 25           1        22              2              1            2
# 26           1        24              2              1            2
# 27           1        20              1              1            2
# 28           1        19              1              1            2
# 29           1        18              1              1            2
# 30           1        21              1              1            2
# 31           1        25              1              1            2
# 32           1        23              1              1            3
# 33           1        28              1              1            3
# 34           1        26              1              1            3

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
import seaborn as sns
sns.heatmap(df.corr(), annot=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = LabelEncoder()
for column in df.columns:
        if df[column].dtype == type(object):
            df[column] = le.fit_transform(df[column])
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import preprocessing
from sklearn import utils
lab_enc = preprocessing.LabelEncoder()
training_scores_encoded = lab_enc.fit_transform(y_train)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train, training_scores_encoded)
y_model = model.predict(x_test)
import seaborn as sns
sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-7d977766ceeb> in <module>
#      18 from sklearn.naive_bayes import GaussianNB
#      19 model = GaussianNB()
# ---> 20 model.fit(x_train, training_scores_encoded)
#      21 y_model = model.predict(x_test)
#      22 import seaborn as sns
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     188         self : object
#     189         """
# --> 190         X, y = check_X_y(X, y)
#     191         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     192                                  sample_weight=sample_weight)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'A'

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, training_scores_encoded)
y_model = model.predict(x1_test)
import seaborn as sns
sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-677608b646dd> in <module>
#      17 from sklearn.naive_bayes import GaussianNB
#      18 model = GaussianNB()
# ---> 19 model.fit(x_train, training_scores_encoded)
#      20 y_model = model.predict(x_test)
#      21 import seaborn as sns
#
# ~\Anaconda3\lib\site-packages\sklearn\naive_bayes.py in fit(self, X, y, sample_weight)
#     188         self : object
#     189         """
# --> 190         X, y = check_X_y(X, y)
#     191         return self._partial_fit(X, y, np.unique(y), _refit=True,
#     192                                  sample_weight=sample_weight)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     565         # make sure we actually converted to numeric:
#     566         if dtype_numeric and array.dtype.kind == "O":
# --> 567             array = array.astype(np.float64)
#     568         if not allow_nd and array.ndim >= 3:
#     569             raise ValueError("Found array with dim %d. %s expected <= 2."
#
# ValueError: could not convert string to float: 'A'

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, training_scores_encoded)
y_model = model.predict(x1_test)
import seaborn as sns
sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-260850ef27d8> in <module>
#      20 y_model = model.predict(x1_test)
#      21 import seaborn as sns
# ---> 22 sns.heatmap(df, square=True, vmax=99, annot=True, cbar=False)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     165         # Determine good default values for the colormapping
#     166         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 167                                     cmap, center, robust)
#     168
#     169         # Sort out the annotations
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     202                                cmap, center, robust):
#     203         """Use some heuristics to set good defaults for colorbar and range."""
# --> 204         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     205         if vmin is None:
#     206             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, training_scores_encoded)
y_model = model.predict(x1_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, training_scores_encoded)
pred_y = model.predict(x1_test)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred_y)
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-8af8e55f2576> in <module>
#      22 from sklearn import metrics
#      23 from sklearn.metrics import accuracy_score
# ---> 24 accuracy_score(y_test, pred_y)
#      25 print(confusion_matrix(y_test, pred_y))
#      26 print(classification_report(y_test, pred_y))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     174
#     175     # Compute accuracy for each possible representation
# --> 176     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     177     check_consistent_length(y_true, y_pred, sample_weight)
#     178     if y_type.startswith('multilabel'):
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      92         y_pred = column_or_1d(y_pred)
#      93         if y_type == "binary":
# ---> 94             unique_values = np.union1d(y_true, y_pred)
#      95             if len(unique_values) > 2:
#      96                 y_type = "multiclass"
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in union1d(ar1, ar2)
#     736     array([1, 2, 3, 4, 6])
#     737     """
# --> 738     return unique(np.concatenate((ar1, ar2), axis=None))
#     739
#     740
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     ar = np.asanyarray(ar)
#     263     if axis is None:
# --> 264         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     265         return _unpack_tuple(ret)
#     266
#
# ~\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310         aux = ar[perm]
#     311     else:
# --> 312         ar.sort()
#     313         aux = ar
#     314     mask = np.empty(aux.shape, dtype=np.bool_)
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
X=df.drop('Test result',axis='columns')
y=df['Test result']
import pylab as pl
df.drop('Test result',axis=1).hist(bins=30, figsize=(9,9))
pl.suptitle("Histogram for each numeric input variable")
plt.show()

# %%
from sklearn import preprocessing
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
X=df.drop('Test result',axis='columns')
y=df['Test result']
import pylab as pl
df.drop('Test result',axis=1).hist(bins=30, figsize=(9,9))
pl.suptitle("Histogram for each numeric input variable")
plt.show()

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x_train,y_train)
clf.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-730facc79c00> in <module>
#      13 from sklearn.svm import SVC
#      14 clf = svm.SVC()
# ---> 15 clf.fit(x_train,y_train)
#      16 clf.score(x,y)
#
# NameError: name 'x_train' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x_train,y_train)
clf.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bdbb08e9cbd6> in <module>
#      10 y=df['Test result']
#      11 y=y.values.reshape(-1,1)
# ---> 12 x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
#      13 from sklearn import metrics, svm
#      14 from sklearn.svm import SVC
#
# NameError: name 'x' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x_train,y_train)
clf.score(x,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-c4e7e6978ef2> in <module>
#      14 from sklearn.svm import SVC
#      15 clf = svm.SVC()
# ---> 16 clf.fit(x_train,y_train)
#      17 clf.score(x,y)
#
# ~\Anaconda3\lib\site-packages\sklearn\svm\base.py in fit(self, X, y, sample_weight)
#     147         X, y = check_X_y(X, y, dtype=np.float64,
#     148                          order='C', accept_sparse='csr',
# --> 149                          accept_large_sparse=False)
#     150         y = self._validate_targets(y)
#     151
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     525             try:
#     526                 warnings.simplefilter('error', ComplexWarning)
# --> 527                 array = np.asarray(array, dtype=dtype, order=order)
#     528             except ComplexWarning:
#     529                 raise ValueError("Complex data not supported\n"
#
# ~\Anaconda3\lib\site-packages\numpy\core\numeric.py in asarray(a, dtype, order)
#     536
#     537     """
# --> 538     return array(a, dtype, copy=False, order=order)
#     539
#     540
#
# ValueError: could not convert string to float: 'A'

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\svm\base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.7142857142857143

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.model_selection import train_test_split
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-8ca3097bd652> in <module>
#      18 from sklearn import metrics
#      19 from sklearn.metrics import classification_report, confusion_matrix
# ---> 20 print(confusion_matrix(y_test, pred_y))
#      21 print(classification_report(y_test, pred_y))
#
# NameError: name 'pred_y' is not defined

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.model_selection import train_test_split
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x1_train, y_train)
pred_y= logreg.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-9-e11bd8fc033a> in <module>
#      16 from sklearn.linear_model import LogisticRegression
#      17 logreg = LogisticRegression()
# ---> 18 pred_y= logreg.predict(x_test)
#      19 from sklearn import metrics
#      20 from sklearn.metrics import classification_report, confusion_matrix
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     279             Predicted class label per sample.
#     280         """
# --> 281         scores = self.decision_function(X)
#     282         if len(scores.shape) == 1:
#     283             indices = (scores > 0).astype(np.int)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in decision_function(self, X)
#     253         if not hasattr(self, 'coef_') or self.coef_ is None:
#     254             raise NotFittedError("This %(name)s instance is not fitted "
# --> 255                                  "yet" % {'name': type(self).__name__})
#     256
#     257         X = check_array(X, accept_sparse='csr')
#
# NotFittedError: This LogisticRegression instance is not fitted yet

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.model_selection import train_test_split
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x1_train, y_train)
pred_y= logreg.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#    micro avg       1.00      1.00      1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.neighbors import KNeighborsClassifier
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
classifier = KNeighborsClassifier()
classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[1 5]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.17      0.29         6
#         P/NP       0.38      1.00      0.55         3
#
#    micro avg       0.44      0.44      0.44         9
#    macro avg       0.69      0.58      0.42         9
# weighted avg       0.79      0.44      0.37         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.neighbors import KNeighborsClassifier
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
classifier = KNeighborsClassifier()
classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
classifier.score(x1_test,y_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# 0.4444444444444444

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.model_selection import train_test_split
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x1_train, y_train)
pred_y= logreg.predict(x1_test)
from sklearn import metrics
logreg.score(x1_test,y_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:460: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# 1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
df.head()
import seaborn as sns
sns.pairplot(df, =2.5)
# Out:
#   File "<ipython-input-14-9e76930f5c95>", line 6
#     sns.pairplot(df, =2.5)
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
df.head()
import seaborn as sns
sns.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2.5
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-8f51dfd3170e> in <module>
#       4 df.head()
#       5 import seaborn as sns
# ----> 6 sns.pairplot(df,2.5)
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, dropna, plot_kws, diag_kws, grid_kws, size)
#    2082                     hue_order=hue_order, palette=palette,
#    2083                     diag_sharey=diag_sharey,
# -> 2084                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2085
#    2086     # Add the markers here as PairGrid has figured out how many levels of the
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, diag_sharey, height, aspect, despine, dropna, size)
#    1288                                       index=data.index)
#    1289         else:
# -> 1290             hue_names = utils.categorical_order(data[hue], hue_order)
#    1291             if dropna:
#    1292                 # Filter NA from the list of unique hue names
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2.5

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
df.head()
import seaborn as sns
sns.pairplot(df)

# %%
import seaborn as sns 
sns.set()
sns.pairplot(df)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, y_train)
y_model = model.predict(x1_test)
from sklearn import metrics
model.score(x1_test,y_test)
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# 1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, y_train)
y_model = model.predict(x1_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_model)
from sklearn.metrics import confusion_matrix
mat = confusion_matrix(y_test, y_model)
sns.heatmap(x1, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Text(182.36857142857144, 0.5, 'true value')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-058b94176a4c> in <module>
#      10 y=df['Test result']
#      11 y=y.values.reshape(-1,1)
# ---> 12 le = preprocessing.LabelEncoder()
#      13 x1 = df.apply(le.fit_transform)
#      14 enc = preprocessing.OneHotEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, y_train)
y_model = model.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_model))
print(classification_report(y_test, y_model))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-74d3bc1b598a> in <module>
#       6 x=df.drop('Test result',axis='columns')
#       7 y=df['Test result']
# ----> 8 le = preprocessing.LabelEncoder()
#       9 x1 = df.apply(le.fit_transform)
#      10 enc = preprocessing.OneHotEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, y_train)
y_model = model.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_model))
print(classification_report(y_test, y_model))
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.neighbors import KNeighborsClassifier
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
classifier = KNeighborsClassifier()
classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# [[1 5]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.17      0.29         6
#         P/NP       0.38      1.00      0.55         3
#
#     accuracy                           0.44         9
#    macro avg       0.69      0.58      0.42         9
# weighted avg       0.79      0.44      0.37         9
# C:\Users\dell\Anaconda3-1\lib\site-packages\ipykernel_launcher.py:17: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
# Out:
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.7142857142857143

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[2 2]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.50      0.67         4
#         P/NP       0.60      1.00      0.75         3
#
#     accuracy                           0.71         7
#    macro avg       0.80      0.75      0.71         7
# weighted avg       0.83      0.71      0.70         7
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3-1\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e52b50776606> in <module>
#       8 X=df.drop('Test result',axis='columns')
#       9 y=df['Test result']
# ---> 10 le = preprocessing.LabelEncoder()
#      11 x1 = df.apply(le.fit_transform)
#      12 enc = preprocessing.OneHotEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
X=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-6c99dbea213e> in <module>
#       1 import seaborn as sns
# ----> 2 mat = confusion_matrix(y_test, y_model)
#       3 sns.heatmap(mat, square=True, annot=True, cbar=False)
#       4 plt.xlabel('predicted value')
#       5 plt.ylabel('true value')
#
# NameError: name 'y_model' is not defined

# %%
y_model= classifier.predict(x1_test)
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# Text(91.68, 0.5, 'true value')

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from IPython.display import Image
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
df=pd.read_csv(r'C:\Users\dell\Desktop\data.csv')
X=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
y=y.values.reshape(-1,1)
from sklearn.model_selection import train_test_split
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
from sklearn.ensemble import RandomForestClassifier
classifier=DecisionTreeClassifier()
classifier=classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import metrics
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
from sklearn.tree import DecisionTreeClassifier
from sklearn import datasets
from IPython.display import Image  
from sklearn import tree
import pydotplus
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(classifier, out_file=dot_data,filled=True, rounded=True,special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= classifier.predict(x1_test)
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-1-9ec107755269> in <module>
#       6 import matplotlib.pyplot as plt
#       7 from sklearn import tree
# ----> 8 df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates')
#       9 x=df.drop('Test result',axis='columns')
#      10 y=df['Test result']
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: Initializing from file failed

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= classifier.predict(x1_test)
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7052ea8a0b56> in <module>
#      10 y=df['Test result']
#      11 y=y.values.reshape(-1,1)
# ---> 12 le = preprocessing.LabelEncoder()
#      13 x1 = df.apply(le.fit_transform)
#      14 enc = preprocessing.OneHotEncoder()
#
# NameError: name 'preprocessing' is not defined

# %%
from sklearn import preprocessing
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= classifier.predict(x1_test)
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# [[2 2]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.50      0.67         4
#         P/NP       0.60      1.00      0.75         3
#
#     accuracy                           0.71         7
#    macro avg       0.80      0.75      0.71         7
# weighted avg       0.83      0.71      0.70         7
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-154319f9e6f5> in <module>
#      27 print(confusion_matrix(y_test, pred_y))
#      28 print(classification_report(y_test, pred_y))
# ---> 29 y_model= classifier.predict(x1_test)
#      30 import seaborn as sns
#      31 mat = confusion_matrix(y_test, y_model)
#
# NameError: name 'classifier' is not defined

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn import metrics, svm
from sklearn.svm import SVC
clf = svm.SVC()
clf.fit(x1_train,y_train)
clf.score(x1_test,y_test)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= clf.predict(x1_test)
# Out:
# [[2 2]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      0.50      0.67         4
#         P/NP       0.60      1.00      0.75         3
#
#     accuracy                           0.71         7
#    macro avg       0.80      0.75      0.71         7
# weighted avg       0.83      0.71      0.70         7
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# Text(91.68, 0.5, 'true value')

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
from sklearn.model_selection import train_test_split
X=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
from sklearn.neighbors import KNeighborsClassifier
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
classifier = KNeighborsClassifier()
classifier.fit(x1_train,y_train)
pred_y= classifier.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= clf.predict(x1_test)
# Out:
#   File "<ipython-input-5-c4871518cabe>", line 25
#     plt.ylabel('true value')print(confusion_matrix(y_test, pred_y))
#                                 ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
from sklearn import tree
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
y=y.values.reshape(-1,1)
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, test_size=0.2,random_state=0)
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier()
clf.fit(x1_train,y_train)
pred_y= clf.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
print(confusion_matrix(y_test, pred_y))
print(classification_report(y_test, pred_y))
y_model= clf.predict(x1_test)
# Out:
# [[1 3]
#  [1 2]]
#               precision    recall  f1-score   support
#
#        NP/NP       0.50      0.25      0.33         4
#         P/NP       0.40      0.67      0.50         3
#
#     accuracy                           0.43         7
#    macro avg       0.45      0.46      0.42         7
# weighted avg       0.46      0.43      0.40         7
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x1_train, y_train)
y_model = model.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_model))
print(classification_report(y_test, y_model))
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# Text(91.68, 0.5, 'true value')

# %%
from sklearn import preprocessing
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
df=pd.read_csv(r'C:\Users\dell\Desktop\Python excersize\Perforated plates.csv')
x=df.drop('Test result',axis='columns')
y=df['Test result']
le = preprocessing.LabelEncoder()
x1 = df.apply(le.fit_transform)
enc = preprocessing.OneHotEncoder()
enc.fit(x1)
onehotlabels = enc.transform(x1).toarray()
x1_train, x1_test, y_train, y_test = train_test_split(x1, y, random_state=0)
y=y.values.reshape(-1,1)
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(x1_train, y_train)
y_model= logreg.predict(x1_test)
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_model))
print(classification_report(y_test, y_model))
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns
mat = confusion_matrix(y_test, y_model)
sns.heatmap(mat, square=True, annot=True, cbar=False)
plt.xlabel('predicted value')
plt.ylabel('true value')
# Out:
# [[6 0]
#  [0 3]]
#               precision    recall  f1-score   support
#
#        NP/NP       1.00      1.00      1.00         6
#         P/NP       1.00      1.00      1.00         3
#
#     accuracy                           1.00         9
#    macro avg       1.00      1.00      1.00         9
# weighted avg       1.00      1.00      1.00         9
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Text(91.68, 0.5, 'true value')
